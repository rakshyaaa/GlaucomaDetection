# %%
import numpy as np
import pandas as pd
import os

# %%
folder = 'C:\\Rakshya\\ULL\\First Semester\\Data Mining\\fairdomain-20241031T021302Z-001\\fairdomain'

# %%
meta = pd.read_csv(os.path.join(folder, 'data_summary.csv'))

# %%
meta
# Out:
#             filename    age  gender   race     ethnicity language  \
# 0     data_00001.npz  72.37  female  white  non-hispanic  english
# 1     data_00002.npz  62.09  female  white  non-hispanic  english
# 2     data_00003.npz  68.70  female  white  non-hispanic  english
# 3     data_00004.npz  57.07  female  white  non-hispanic  english
# 4     data_00005.npz  47.59    male  white  non-hispanic  english
# ...              ...    ...     ...    ...           ...      ...
# 4995  data_09996.npz  59.12  female  white  non-hispanic  english
# 4996  data_09997.npz  62.00  female  white  non-hispanic  english
# 4997  data_09998.npz  77.10  female  white  non-hispanic  english
# 4998  data_09999.npz  44.76  female  white  non-hispanic  english
# 4999  data_10000.npz  64.00  female  black  non-hispanic  english
#
#              maritalstatus     md glaucoma       use
# 0                  widowed -22.93      yes  training
# 1                 divorced   1.48       no  training
# 2     married or partnered -19.61      yes  training
# 3     married or partnered   1.13       no  training
# 4                   single   0.44       no  training
# ...                    ...    ...      ...       ...
# 4995  married or partnered   0.16       no   testing
# 4996  married or partnered   0.41       no   testing
# 4997               widowed  -9.54      yes   testing
# 4998  married or partnered   0.74       no   testing
# 4999  married or partnered  -9.05      yes   testing
#
# [5000 rows x 10 columns]

# %%
data = np.load(os.path.join(folder,'Training','data_00001.npz'))

# %%
for k in data.keys():
    print(k)
# Out:
# oct_fundus
# slo_fundus
# age
# gender
# race
# ethnicity
# language
# marriagestatus
# md
# glaucoma

# %%
data['oct_fundus']
# Out:
# array([[197, 182, 177, ..., 170, 152, 147],
#        [193, 191, 189, ..., 146, 135, 138],
#        [184, 191, 197, ..., 150, 149, 141],
#        ...,
#        [189, 185, 188, ..., 192, 186, 187],
#        [192, 186, 185, ..., 200, 191, 191],
#        [169, 195, 191, ..., 198, 189, 187]], dtype=uint8)
