# %%
import numpy as np
import pandas as pd
import os

# %%
folder = 'C:\\Rakshya\\ULL\\First Semester\\Data Mining\\fairdomain-20241031T021302Z-001\\fairdomain'

# %%
data = np.load(os.path.join(folder, 'Training', 'data_00001.npz'))

# %%
for k in data.keys():
    print(k)
# Out:
# oct_fundus
# slo_fundus
# age
# gender
# race
# ethnicity
# language
# marriagestatus
# md
# glaucoma

# %%
data['oct_fundus']
# Out:
# array([[197, 182, 177, ..., 170, 152, 147],
#        [193, 191, 189, ..., 146, 135, 138],
#        [184, 191, 197, ..., 150, 149, 141],
#        ...,
#        [189, 185, 188, ..., 192, 186, 187],
#        [192, 186, 185, ..., 200, 191, 191],
#        [169, 195, 191, ..., 198, 189, 187]], dtype=uint8)

# %%
data['slo_fundus']
# Out:
# array([[25, 27, 20, ..., 20, 29, 11],
#        [16, 26, 23, ..., 19, 14,  5],
#        [21, 22, 23, ..., 14,  9, 11],
#        ...,
#        [22, 32, 39, ..., 11,  4, 10],
#        [47, 35, 43, ..., 15,  5,  7],
#        [25, 22, 32, ..., 11,  5, 14]], dtype=uint8)

# %%
data['slo_fundus'].shape
# Out:
# (224, 224)

# %%
data['oct_fundus'].shape
# Out:
# (224, 224)

# %%
import matplotlib.pyplot as plt
plt.imshow(data['oct_fundus'],cmap='gray')

plt.show()

# %%
data = np.load(os.path.join(folder, 'Training', 'data_00001.npz'))

# %%
data['marriagestatus']
# Out:
# array(3)

# %%
data['glaucoma']
# Out:
# array(1)
